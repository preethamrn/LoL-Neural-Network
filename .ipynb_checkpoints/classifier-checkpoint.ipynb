# %%
import pickle
import numpy as np

gameData = list()
champions = list()

with open('gameData.pickle', 'rb') as f:
    gameData = pickle.load(f)
with open('champions.pickle', 'rb') as f:
    champions = pickle.load(f)

# convert the games into data that can be fed into Tensorflow
games = list()
winners = list()
winners_categorical = list()
roles = ['Top', 'Jungle', 'Middle', 'Support', 'ADC']

for game in gameData:
    g = np.zeros(1380)
    w = np.zeros(2)
    stat_index = 0
    for k, v in game.items():
        if k.startswith('t0p'):
            i = ['t0p_top_lane_champID', 't0p_jungle_champID', 't0p_mid_lane_champID', 't0p_support_champID', 't0p_ad_carry_champID'].index(k)
            g[len(champions)*i + champions[v]['smallID']] = 1
        elif k.startswith('t0'):
            g[stat_index] = v
            stat_index += 1
        elif k.startswith('t1p'):
            i = ['t1p_top_lane_champID', 't1p_jungle_champID', 't1p_mid_lane_champID', 't1p_support_champID', 't1p_ad_carry_champID'].index(k)
            g[len(champions)*(5+i) + champions[v]['smallID']] = 1
        elif k.startswith('t1'):
            g[stat_index] = v
            stat_index += 1
    w[game['winner']] = 1
    games.append(g)
    winners.append(w)
    winners_categorical.append(game['winner'])

# %%
# using RandomForestClassifier
from sklearn.ensemble import RandomForestClassifier
from scipy.stats import kendalltau, spearmanr

# create test train split
from sklearn.cross_validation import train_test_split
X_train, X_test, y_train, y_test = train_test_split(games, winners_categorical, test_size=0.30, random_state=42)

clf = RandomForestClassifier(n_estimators=100, oob_score=True)
clf.fit(X_train, y_train)

predicted_results = clf.predict(X_test)
r2 = clf.score(X_test, y_test)

t, t_p = kendalltau(predicted_results, y_test)
r, r_p = spearmanr(predicted_results, y_test)

print(r2)
print(t, t_p)
print(r, r_p)


print('----FEATURE IMPORTANCES----')

importances = clf.feature_importances_
indices = np.argsort(importances)[::-1]
features = list()

for i in range(1340):
    features.append(['t0p_top_lane_champID', 't0p_jungle_champID', 't0p_mid_lane_champID', 
                     't0p_support_champID', 't0p_ad_carry_champID','t1p_top_lane_champID', 
                     't1p_jungle_champID', 't1p_mid_lane_champID', 't1p_support_champID', 't1p_ad_carry_champID'][int(i/134)] + str(i%134))
for feature in gameData[0]:
    if feature.startswith('t0p') or feature.startswith('t1p'):
        features.append(feature)
    
for i, f in enumerate(features):
    print("%d. %s (%f)" % (i+1, features[indices[i]], importances[indices[i]]))
# Out:
# 0.531055900621
# 0.0592651229681 0.0244581304087
# 0.0598254399941 0.129365525129
# ----FEATURE IMPORTANCES----
# 1. t0p_top_lane_champID33 (0.025010)
# 2. t0p_top_lane_champID16 (0.024985)
# 3. t0p_top_lane_champID37 (0.024096)
# 4. t0p_top_lane_champID31 (0.023840)
# 5. t0p_top_lane_champID28 (0.023590)
# 6. t0p_top_lane_champID23 (0.022517)
# 7. t0p_top_lane_champID8 (0.022508)
# 8. t0p_top_lane_champID15 (0.022111)
# 9. t0p_top_lane_champID30 (0.021558)
# 10. t0p_top_lane_champID9 (0.021208)
# 11. t0p_top_lane_champID35 (0.021146)
# 12. t0p_top_lane_champID3 (0.021110)
# 13. t0p_top_lane_champID21 (0.020865)
# 14. t0p_top_lane_champID19 (0.020730)
# 15. t0p_top_lane_champID2 (0.019299)
# 16. t0p_top_lane_champID36 (0.018889)
# 17. t0p_top_lane_champID20 (0.018644)
# 18. t0p_top_lane_champID38 (0.018571)
# 19. t0p_top_lane_champID4 (0.016199)
# 20. t0p_top_lane_champID7 (0.015964)
# 21. t0p_top_lane_champID14 (0.015125)
# 22. t0p_top_lane_champID22 (0.015052)
# 23. t0p_top_lane_champID32 (0.013908)
# 24. t0p_top_lane_champID12 (0.013629)
# 25. t0p_top_lane_champID6 (0.012777)
# 26. t0p_top_lane_champID5 (0.012111)
# 27. t0p_top_lane_champID11 (0.012102)
# 28. t0p_top_lane_champID10 (0.010649)
# 29. t0p_top_lane_champID18 (0.009684)
# 30. t0p_top_lane_champID26 (0.008787)
# 31. t0p_top_lane_champID27 (0.008647)
# 32. t0p_top_lane_champID39 (0.007915)
# 33. t0p_top_lane_champID13 (0.007707)
# 34. t0p_top_lane_champID112 (0.005070)
# 35. t1p_top_lane_champID112 (0.004834)
# 36. t0p_support_champID81 (0.004618)
# 37. t0p_top_lane_champID1 (0.004594)
# 38. t1p_ad_carry_champID12 (0.004512)
# 39. t0p_ad_carry_champID12 (0.004456)
# 40. t1p_jungle_champID6 (0.004250)
# 41. t1p_ad_carry_champID37 (0.004205)
# 42. t1p_jungle_champID5 (0.004157)
# 43. t0p_jungle_champID6 (0.004157)
# 44. t1p_ad_carry_champID14 (0.004085)
# 45. t1p_ad_carry_champID29 (0.004041)
# 46. t0p_support_champID18 (0.003929)
# 47. t0p_mid_lane_champID25 (0.003916)
# 48. t1p_mid_lane_champID25 (0.003768)
# 49. t0p_jungle_champID5 (0.003754)
# 50. t0p_ad_carry_champID8 (0.003628)
# 51. t1p_support_champID18 (0.003533)
# 52. t1p_mid_lane_champID17 (0.003527)
# 53. t0p_jungle_champID63 (0.003473)
# 54. t0p_mid_lane_champID17 (0.003412)
# 55. t0p_top_lane_champID46 (0.003410)
# 56. t0p_ad_carry_champID37 (0.003328)
# 57. t1p_support_champID81 (0.003304)
# 58. t0p_top_lane_champID24 (0.003301)
# 59. t1p_support_champID16 (0.003290)
# 60. t1p_jungle_champID63 (0.003187)
# 61. t0p_ad_carry_champID41 (0.003166)
# 62. t1p_top_lane_champID3 (0.003136)
# 63. t1p_jungle_champID33 (0.002988)
# 64. t0p_support_champID66 (0.002938)
# 65. t0p_jungle_champID33 (0.002904)
# 66. t0p_ad_carry_champID29 (0.002900)
# 67. t1p_support_champID66 (0.002894)
# 68. t1p_ad_carry_champID128 (0.002869)
# 69. t1p_top_lane_champID1 (0.002865)
# 70. t0p_ad_carry_champID19 (0.002849)
# 71. t0p_ad_carry_champID14 (0.002784)
# 72. t1p_jungle_champID30 (0.002772)
# 73. t0p_ad_carry_champID75 (0.002735)
# 74. t1p_support_champID44 (0.002611)
# 75. t1p_top_lane_champID46 (0.002589)
# 76. t1p_support_champID15 (0.002573)
# 77. t1p_ad_carry_champID75 (0.002567)
# 78. t1p_top_lane_champID0 (0.002552)
# 79. t0p_support_champID35 (0.002539)
# 80. t0p_top_lane_champID0 (0.002478)
# 81. t1p_ad_carry_champID19 (0.002477)
# 82. t0p_mid_lane_champID32 (0.002469)
# 83. t1p_ad_carry_champID41 (0.002411)
# 84. t0p_mid_lane_champID66 (0.002396)
# 85. t1p_top_lane_champID103 (0.002372)
# 86. t1p_ad_carry_champID40 (0.002368)
# 87. t0p_mid_lane_champID27 (0.002355)
# 88. t1p_mid_lane_champID32 (0.002347)
# 89. t0p_top_lane_champID103 (0.002344)
# 90. t0p_top_lane_champID67 (0.002267)
# 91. t1p_support_champID35 (0.002195)
# 92. t0p_mid_lane_champID38 (0.002169)
# 93. t0p_support_champID71 (0.002161)
# 94. t0p_top_lane_champID123 (0.002156)
# 95. t0p_ad_carry_champID128 (0.002125)
# 96. t1p_jungle_champID126 (0.002091)
# 97. t1p_jungle_champID24 (0.002081)
# 98. t0p_support_champID44 (0.002060)
# 99. t0p_jungle_champID7 (0.002059)
# 100. t1p_mid_lane_champID43 (0.002036)
# 101. t1p_top_lane_champID67 (0.002029)
# 102. t0p_support_champID125 (0.001997)
# 103. t0p_mid_lane_champID90 (0.001974)
# 104. t0p_mid_lane_champID11 (0.001971)
# 105. t1p_ad_carry_champID72 (0.001958)
# 106. t0p_jungle_champID30 (0.001948)
# 107. t1p_jungle_champID7 (0.001934)
# 108. t1p_mid_lane_champID48 (0.001927)
# 109. t1p_mid_lane_champID45 (0.001916)
# 110. t0p_top_lane_champID95 (0.001884)
# 111. t0p_support_champID16 (0.001872)
# 112. t0p_mid_lane_champID68 (0.001871)
# 113. t1p_top_lane_champID10 (0.001862)
# 114. t1p_mid_lane_champID11 (0.001862)
# 115. t0p_ad_carry_champID72 (0.001857)
# 116. t0p_top_lane_champID107 (0.001843)
# 117. t1p_mid_lane_champID42 (0.001839)
# 118. t1p_ad_carry_champID8 (0.001831)
# 119. t1p_mid_lane_champID27 (0.001816)
# 120. t0p_mid_lane_champID48 (0.001780)
# 121. t0p_support_champID67 (0.001777)
# 122. t1p_top_lane_champID107 (0.001775)
# 123. t0p_support_champID36 (0.001770)
# 124. t0p_mid_lane_champID43 (0.001759)
# 125. t1p_support_champID31 (0.001757)
# 126. t0p_support_champID15 (0.001752)
# 127. t1p_top_lane_champID38 (0.001714)
# 128. t1p_support_champID36 (0.001712)
# 129. t0p_support_champID70 (0.001711)
# 130. t0p_jungle_champID126 (0.001707)
# 131. t1p_mid_lane_champID19 (0.001656)
# 132. t1p_support_champID67 (0.001656)
# 133. t0p_ad_carry_champID28 (0.001652)
# 134. t1p_top_lane_champID21 (0.001651)
# 135. t1p_top_lane_champID123 (0.001613)
# 136. t0p_support_champID31 (0.001611)
# 137. t1p_mid_lane_champID66 (0.001596)
# 138. t1p_mid_lane_champID55 (0.001593)
# 139. t0p_top_lane_champID48 (0.001590)
# 140. t1p_top_lane_champID95 (0.001543)
# 141. t1p_support_champID70 (0.001531)
# 142. t0p_jungle_champID24 (0.001513)
# 143. t0p_mid_lane_champID55 (0.001510)
# 144. t0p_support_champID69 (0.001509)
# 145. t0p_mid_lane_champID42 (0.001472)
# 146. t1p_top_lane_champID2 (0.001438)
# 147. t1p_mid_lane_champID130 (0.001437)
# 148. t0p_jungle_champID22 (0.001416)
# 149. t1p_support_champID125 (0.001401)
# 150. t0p_jungle_champID46 (0.001386)
# 151. t0p_jungle_champID104 (0.001372)
# 152. t1p_mid_lane_champID26 (0.001348)
# 153. t0p_mid_lane_champID19 (0.001344)
# 154. t0p_support_champID60 (0.001336)
# 155. t1p_mid_lane_champID64 (0.001331)
# 156. t1p_mid_lane_champID90 (0.001324)
# 157. t1p_jungle_champID22 (0.001296)
# 158. t1p_top_lane_champID15 (0.001295)
# 159. t0p_mid_lane_champID78 (0.001290)
# 160. t1p_jungle_champID46 (0.001285)
# 161. t0p_ad_carry_champID40 (0.001282)
# 162. t1p_mid_lane_champID38 (0.001277)
# 163. t1p_support_champID60 (0.001223)
# 164. t1p_mid_lane_champID68 (0.001208)
# 165. t1p_jungle_champID2 (0.001203)
# 166. t1p_jungle_champID76 (0.001197)
# 167. t0p_ad_carry_champID18 (0.001162)
# 168. t1p_ad_carry_champID28 (0.001150)
# 169. t1p_mid_lane_champID53 (0.001147)
# 170. t1p_mid_lane_champID8 (0.001137)
# 171. t0p_mid_lane_champID123 (0.001133)
# 172. t1p_mid_lane_champID78 (0.001131)
# 173. t0p_support_champID98 (0.001129)
# 174. t1p_mid_lane_champID46 (0.001114)
# 175. t0p_mid_lane_champID45 (0.001067)
# 176. t0p_jungle_champID42 (0.001042)
# 177. t0p_ad_carry_champID13 (0.001033)
# 178. t1p_top_lane_champID39 (0.001029)
# 179. t0p_top_lane_champID104 (0.001020)
# 180. t1p_mid_lane_champID10 (0.001018)
# 181. t1p_top_lane_champID104 (0.001012)
# 182. t1p_top_lane_champID5 (0.001012)
# 183. t0p_jungle_champID2 (0.000993)
# 184. t0p_top_lane_champID47 (0.000991)
# 185. t0p_jungle_champID25 (0.000988)
# 186. t0p_mid_lane_champID108 (0.000985)
# 187. t1p_top_lane_champID86 (0.000981)
# 188. t1p_support_champID69 (0.000975)
# 189. t0p_support_champID84 (0.000959)
# 190. t0p_mid_lane_champID130 (0.000941)
# 191. t0p_mid_lane_champID20 (0.000937)
# 192. t1p_jungle_champID104 (0.000937)
# 193. t0p_top_lane_champID98 (0.000934)
# 194. t0p_mid_lane_champID53 (0.000917)
# 195. t1p_mid_lane_champID123 (0.000908)
# 196. t0p_jungle_champID62 (0.000904)
# 197. t1p_jungle_champID34 (0.000902)
# 198. t0p_support_champID5 (0.000889)
# 199. t1p_jungle_champID4 (0.000871)
# 200. t1p_mid_lane_champID101 (0.000828)
# 201. t1p_mid_lane_champID129 (0.000823)
# 202. t0p_top_lane_champID87 (0.000822)
# 203. t1p_top_lane_champID30 (0.000819)
# 204. t1p_ad_carry_champID13 (0.000787)
# 205. t0p_ad_carry_champID16 (0.000779)
# 206. t0p_support_champID103 (0.000776)
# 207. t1p_top_lane_champID50 (0.000776)
# 208. t0p_top_lane_champID50 (0.000765)
# 209. t1p_support_champID71 (0.000765)
# 210. t0p_ad_carry_champID30 (0.000760)
# 211. t1p_mid_lane_champID41 (0.000754)
# 212. t0p_mid_lane_champID37 (0.000749)
# 213. t0p_mid_lane_champID26 (0.000747)
# 214. t0p_mid_lane_champID82 (0.000743)
# 215. t1p_top_lane_champID125 (0.000739)
# 216. t0p_mid_lane_champID46 (0.000738)
# 217. t0p_mid_lane_champID12 (0.000717)
# 218. t1p_top_lane_champID48 (0.000695)
# 219. t1p_jungle_champID62 (0.000682)
# 220. t0p_mid_lane_champID56 (0.000678)
# 221. t1p_top_lane_champID98 (0.000671)
# 222. t1p_mid_lane_champID82 (0.000668)
# 223. t0p_top_lane_champID68 (0.000665)
# 224. t1p_top_lane_champID68 (0.000652)
# 225. t1p_top_lane_champID87 (0.000648)
# 226. t1p_support_champID12 (0.000646)
# 227. t1p_ad_carry_champID18 (0.000638)
# 228. t0p_top_lane_champID82 (0.000628)
# 229. t0p_mid_lane_champID64 (0.000608)
# 230. t1p_support_champID79 (0.000608)
# 231. t0p_support_champID58 (0.000604)
# 232. t0p_mid_lane_champID10 (0.000603)
# 233. t1p_ad_carry_champID65 (0.000598)
# 234. t0p_mid_lane_champID41 (0.000592)
# 235. t0p_jungle_champID4 (0.000591)
# 236. t1p_support_champID58 (0.000574)
# 237. t1p_mid_lane_champID56 (0.000572)
# 238. t1p_mid_lane_champID20 (0.000567)
# 239. t0p_mid_lane_champID18 (0.000565)
# 240. t0p_ad_carry_champID15 (0.000552)
# 241. t1p_mid_lane_champID86 (0.000551)
# 242. t0p_mid_lane_champID13 (0.000547)
# 243. t0p_top_lane_champID86 (0.000546)
# 244. t1p_ad_carry_champID15 (0.000541)
# 245. t0p_ad_carry_champID36 (0.000537)
# 246. t1p_ad_carry_champID16 (0.000529)
# 247. t0p_support_champID6 (0.000522)
# 248. t0p_top_lane_champID59 (0.000521)
# 249. t1p_ad_carry_champID49 (0.000520)
# 250. t1p_ad_carry_champID44 (0.000518)
# 251. t0p_mid_lane_champID86 (0.000509)
# 252. t0p_ad_carry_champID44 (0.000491)
# 253. t1p_top_lane_champID59 (0.000487)
# 254. t1p_top_lane_champID82 (0.000487)
# 255. t0p_ad_carry_champID65 (0.000484)
# 256. t1p_top_lane_champID27 (0.000473)
# 257. t0p_top_lane_champID125 (0.000470)
# 258. t1p_ad_carry_champID111 (0.000459)
# 259. t0p_mid_lane_champID8 (0.000449)
# 260. t0p_jungle_champID29 (0.000448)
# 261. t1p_mid_lane_champID12 (0.000441)
# 262. t0p_top_lane_champID88 (0.000428)
# 263. t0p_mid_lane_champID28 (0.000426)
# 264. t0p_support_champID1 (0.000423)
# 265. t0p_support_champID17 (0.000422)
# 266. t1p_support_champID25 (0.000414)
# 267. t1p_ad_carry_champID122 (0.000410)
# 268. t0p_top_lane_champID61 (0.000403)
# 269. t1p_jungle_champID17 (0.000395)
# 270. t0p_support_champID107 (0.000395)
# 271. t0p_jungle_champID82 (0.000393)
# 272. t1p_mid_lane_champID15 (0.000391)
# 273. t1p_ad_carry_champID31 (0.000390)
# 274. t1p_support_champID19 (0.000389)
# 275. t1p_mid_lane_champID18 (0.000376)
# 276. t0p_ad_carry_champID49 (0.000373)
# 277. t0p_jungle_champID34 (0.000370)
# 278. t0p_top_lane_champID127 (0.000367)
# 279. t1p_ad_carry_champID81 (0.000363)
# 280. t0p_mid_lane_champID29 (0.000362)
# 281. t1p_support_champID103 (0.000353)
# 282. t0p_ad_carry_champID31 (0.000352)
# 283. t0p_ad_carry_champID42 (0.000349)
# 284. t1p_support_champID6 (0.000335)
# 285. t1p_top_lane_champID20 (0.000323)
# 286. t1p_jungle_champID25 (0.000322)
# 287. t0p_support_champID48 (0.000312)
# 288. t0p_top_lane_champID115 (0.000312)
# 289. t0p_ad_carry_champID98 (0.000309)
# 290. t1p_top_lane_champID115 (0.000305)
# 291. t0p_ad_carry_champID111 (0.000304)
# 292. t1p_ad_carry_champID42 (0.000303)
# 293. t1p_jungle_champID29 (0.000298)
# 294. t1p_mid_lane_champID124 (0.000292)
# 295. t0p_jungle_champID76 (0.000289)
# 296. t0p_mid_lane_champID97 (0.000287)
# 297. t0p_jungle_champID11 (0.000286)
# 298. t0p_top_lane_champID74 (0.000284)
# 299. t1p_ad_carry_champID36 (0.000283)
# 300. t0p_mid_lane_champID101 (0.000282)
# 301. t0p_support_champID78 (0.000280)
# 302. t1p_mid_lane_champID21 (0.000275)
# 303. t0p_jungle_champID17 (0.000274)
# 304. t1p_mid_lane_champID34 (0.000272)
# 305. t0p_ad_carry_champID24 (0.000270)
# 306. t1p_support_champID29 (0.000269)
# 307. t1p_top_lane_champID7 (0.000265)
# 308. t0p_jungle_champID113 (0.000262)
# 309. t1p_support_champID107 (0.000257)
# 310. t1p_mid_lane_champID9 (0.000256)
# 311. t0p_support_champID24 (0.000251)
# 312. t1p_mid_lane_champID31 (0.000249)
# 313. t1p_support_champID5 (0.000245)
# 314. t1p_top_lane_champID47 (0.000238)
# 315. t0p_mid_lane_champID52 (0.000233)
# 316. t0p_jungle_champID43 (0.000231)
# 317. t0p_jungle_champID12 (0.000227)
# 318. t0p_support_champID38 (0.000227)
# 319. t0p_ad_carry_champID6 (0.000226)
# 320. t1p_support_champID24 (0.000225)
# 321. t1p_top_lane_champID74 (0.000224)
# 322. t1p_mid_lane_champID77 (0.000224)
# 323. t1p_jungle_champID19 (0.000224)
# 324. t0p_support_champID7 (0.000222)
# 325. t1p_mid_lane_champID99 (0.000221)
# 326. t1p_top_lane_champID61 (0.000220)
# 327. t0p_mid_lane_champID104 (0.000218)
# 328. t1p_jungle_champID23 (0.000217)
# 329. t0p_ad_carry_champID81 (0.000213)
# 330. t0p_support_champID2 (0.000213)
# 331. t0p_jungle_champID8 (0.000205)
# 332. t0p_jungle_champID45 (0.000205)
# 333. t0p_support_champID42 (0.000204)
# 334. t0p_ad_carry_champID33 (0.000202)
# 335. t1p_jungle_champID13 (0.000201)
# 336. t1p_jungle_champID94 (0.000199)
# 337. t1p_mid_lane_champID40 (0.000198)
# 338. t1p_ad_carry_champID25 (0.000195)
# 339. t0p_mid_lane_champID31 (0.000193)
# 340. t1p_support_champID63 (0.000193)
# 341. t1p_mid_lane_champID115 (0.000193)
# 342. t1p_top_lane_champID34 (0.000192)
# 343. t1p_jungle_champID42 (0.000191)
# 344. t1p_support_champID84 (0.000189)
# 345. t0p_support_champID19 (0.000187)
# 346. t0p_support_champID21 (0.000184)
# 347. t0p_mid_lane_champID74 (0.000183)
# 348. t0p_mid_lane_champID9 (0.000180)
# 349. t1p_support_champID98 (0.000180)
# 350. t1p_jungle_champID41 (0.000179)
# 351. t0p_support_champID41 (0.000179)
# 352. t0p_jungle_champID1 (0.000179)
# 353. t1p_jungle_champID83 (0.000178)
# 354. t1p_top_lane_champID6 (0.000177)
# 355. t0p_mid_lane_champID21 (0.000176)
# 356. t0p_mid_lane_champID72 (0.000174)
# 357. t1p_top_lane_champID92 (0.000170)
# 358. t0p_support_champID29 (0.000169)
# 359. t0p_jungle_champID88 (0.000167)
# 360. t1p_ad_carry_champID17 (0.000166)
# 361. t1p_top_lane_champID11 (0.000166)
# 362. t0p_support_champID25 (0.000165)
# 363. t1p_ad_carry_champID103 (0.000164)
# 364. t0p_top_lane_champID96 (0.000163)
# 365. t1p_ad_carry_champID30 (0.000162)
# 366. t1p_mid_lane_champID14 (0.000162)
# 367. t1p_ad_carry_champID46 (0.000161)
# 368. t1p_jungle_champID12 (0.000161)
# 369. t0p_jungle_champID32 (0.000161)
# 370. t1p_ad_carry_champID21 (0.000160)
# 371. t0p_mid_lane_champID67 (0.000158)
# 372. t0p_support_champID46 (0.000158)
# 373. t1p_support_champID39 (0.000158)
# 374. t1p_top_lane_champID17 (0.000152)
# 375. t0p_ad_carry_champID5 (0.000151)
# 376. t1p_jungle_champID48 (0.000150)
# 377. t0p_ad_carry_champID43 (0.000149)
# 378. t0p_top_lane_champID75 (0.000147)
# 379. t1p_mid_lane_champID16 (0.000146)
# 380. t0p_ad_carry_champID67 (0.000145)
# 381. t1p_jungle_champID43 (0.000145)
# 382. t0p_jungle_champID3 (0.000145)
# 383. t1p_top_lane_champID131 (0.000142)
# 384. t0p_ad_carry_champID122 (0.000142)
# 385. t0p_mid_lane_champID75 (0.000138)
# 386. t1p_mid_lane_champID30 (0.000138)
# 387. t0p_support_champID12 (0.000137)
# 388. t0p_mid_lane_champID54 (0.000137)
# 389. t0p_ad_carry_champID17 (0.000137)
# 390. t1p_top_lane_champID41 (0.000136)
# 391. t1p_top_lane_champID26 (0.000135)
# 392. t1p_jungle_champID11 (0.000133)
# 393. t1p_jungle_champID117 (0.000133)
# 394. t0p_support_champID75 (0.000132)
# 395. t0p_jungle_champID73 (0.000132)
# 396. t1p_jungle_champID26 (0.000129)
# 397. t1p_support_champID28 (0.000129)
# 398. t1p_jungle_champID55 (0.000129)
# 399. t0p_jungle_champID23 (0.000128)
# 400. t0p_ad_carry_champID4 (0.000126)
# 401. t1p_support_champID22 (0.000125)
# 402. t1p_mid_lane_champID108 (0.000125)
# 403. t0p_mid_lane_champID114 (0.000125)
# 404. t1p_support_champID61 (0.000125)
# 405. t1p_mid_lane_champID29 (0.000124)
# 406. t0p_support_champID30 (0.000123)
# 407. t1p_support_champID55 (0.000121)
# 408. t1p_top_lane_champID76 (0.000120)
# 409. t0p_mid_lane_champID124 (0.000119)
# 410. t1p_mid_lane_champID7 (0.000119)
# 411. t0p_jungle_champID55 (0.000118)
# 412. t1p_ad_carry_champID0 (0.000117)
# 413. t1p_support_champID48 (0.000116)
# 414. t1p_mid_lane_champID75 (0.000113)
# 415. t1p_ad_carry_champID5 (0.000113)
# 416. t1p_jungle_champID57 (0.000113)
# 417. t0p_mid_lane_champID36 (0.000113)
# 418. t1p_support_champID75 (0.000112)
# 419. t1p_mid_lane_champID49 (0.000112)
# 420. t1p_top_lane_champID88 (0.000111)
# 421. t1p_jungle_champID10 (0.000111)
# 422. t0p_jungle_champID117 (0.000111)
# 423. t0p_support_champID43 (0.000111)
# 424. t1p_support_champID1 (0.000110)
# 425. t1p_top_lane_champID96 (0.000110)
# 426. t1p_support_champID10 (0.000105)
# 427. t1p_support_champID7 (0.000104)
# 428. t0p_mid_lane_champID44 (0.000104)
# 429. t1p_mid_lane_champID13 (0.000102)
# 430. t1p_support_champID34 (0.000102)
# 431. t1p_support_champID4 (0.000101)
# 432. t1p_support_champID17 (0.000101)
# 433. t1p_jungle_champID45 (0.000101)
# 434. t1p_ad_carry_champID66 (0.000100)
# 435. t1p_support_champID11 (0.000100)
# 436. t1p_support_champID0 (0.000099)
# 437. t0p_support_champID40 (0.000098)
# 438. t0p_mid_lane_champID15 (0.000098)
# 439. t1p_jungle_champID124 (0.000093)
# 440. t1p_support_champID3 (0.000091)
# 441. t1p_ad_carry_champID3 (0.000089)
# 442. t1p_mid_lane_champID52 (0.000089)
# 443. t1p_jungle_champID113 (0.000088)
# 444. t0p_support_champID45 (0.000087)
# 445. t0p_jungle_champID41 (0.000086)
# 446. t1p_jungle_champID38 (0.000086)
# 447. t1p_support_champID33 (0.000084)
# 448. t1p_mid_lane_champID36 (0.000083)
# 449. t0p_support_champID55 (0.000083)
# 450. t0p_mid_lane_champID63 (0.000082)
# 451. t0p_jungle_champID48 (0.000082)
# 452. t1p_top_lane_champID33 (0.000082)
# 453. t1p_ad_carry_champID53 (0.000081)
# 454. t1p_top_lane_champID62 (0.000080)
# 455. t0p_mid_lane_champID40 (0.000079)
# 456. t0p_support_champID102 (0.000079)
# 457. t1p_ad_carry_champID70 (0.000079)
# 458. t1p_jungle_champID20 (0.000079)
# 459. t1p_support_champID114 (0.000078)
# 460. t1p_support_champID76 (0.000075)
# 461. t1p_top_lane_champID90 (0.000074)
# 462. t1p_top_lane_champID127 (0.000074)
# 463. t0p_support_champID99 (0.000073)
# 464. t0p_mid_lane_champID39 (0.000073)
# 465. t0p_jungle_champID57 (0.000070)
# 466. t0p_jungle_champID37 (0.000069)
# 467. t0p_support_champID28 (0.000069)
# 468. t1p_top_lane_champID55 (0.000068)
# 469. t0p_support_champID82 (0.000068)
# 470. t1p_ad_carry_champID35 (0.000067)
# 471. t0p_mid_lane_champID115 (0.000066)
# 472. t1p_jungle_champID61 (0.000066)
# 473. t1p_mid_lane_champID67 (0.000066)
# 474. t1p_jungle_champID32 (0.000065)
# 475. t0p_mid_lane_champID49 (0.000065)
# 476. t0p_top_lane_champID92 (0.000064)
# 477. t1p_mid_lane_champID6 (0.000064)
# 478. t0p_mid_lane_champID30 (0.000063)
# 479. t0p_mid_lane_champID14 (0.000063)
# 480. t0p_jungle_champID101 (0.000062)
# 481. t1p_ad_carry_champID2 (0.000062)
# 482. t1p_mid_lane_champID44 (0.000062)
# 483. t0p_support_champID11 (0.000061)
# 484. t0p_jungle_champID53 (0.000060)
# 485. t1p_top_lane_champID25 (0.000060)
# 486. t0p_mid_lane_champID129 (0.000060)
# 487. t0p_jungle_champID10 (0.000060)
# 488. t0p_support_champID27 (0.000059)
# 489. t0p_jungle_champID28 (0.000059)
# 490. t1p_jungle_champID96 (0.000058)
# 491. t0p_jungle_champID102 (0.000058)
# 492. t1p_jungle_champID15 (0.000057)
# 493. t1p_top_lane_champID119 (0.000057)
# 494. t0p_mid_lane_champID73 (0.000056)
# 495. t1p_jungle_champID88 (0.000056)
# 496. t1p_top_lane_champID66 (0.000055)
# 497. t0p_jungle_champID19 (0.000055)
# 498. t1p_top_lane_champID54 (0.000054)
# 499. t1p_mid_lane_champID98 (0.000051)
# 500. t0p_mid_lane_champID33 (0.000051)
# 501. t1p_jungle_champID9 (0.000050)
# 502. t1p_top_lane_champID73 (0.000050)
# 503. t0p_ad_carry_champID10 (0.000048)
# 504. t0p_support_champID10 (0.000047)
# 505. t0p_ad_carry_champID25 (0.000047)
# 506. t1p_top_lane_champID89 (0.000047)
# 507. t0p_support_champID50 (0.000047)
# 508. t0p_top_lane_champID91 (0.000046)
# 509. t0p_mid_lane_champID1 (0.000046)
# 510. t0p_ad_carry_champID38 (0.000044)
# 511. t0p_ad_carry_champID103 (0.000044)
# 512. t1p_support_champID47 (0.000044)
# 513. t0p_jungle_champID83 (0.000044)
# 514. t1p_mid_lane_champID37 (0.000043)
# 515. t1p_jungle_champID54 (0.000043)
# 516. t1p_jungle_champID28 (0.000043)
# 517. t0p_mid_lane_champID81 (0.000042)
# 518. t1p_mid_lane_champID58 (0.000042)
# 519. t1p_jungle_champID0 (0.000042)
# 520. t0p_top_lane_champID90 (0.000040)
# 521. t1p_support_champID104 (0.000040)
# 522. t1p_ad_carry_champID6 (0.000039)
# 523. t0p_jungle_champID38 (0.000039)
# 524. t1p_support_champID27 (0.000038)
# 525. t0p_mid_lane_champID34 (0.000038)
# 526. t0p_mid_lane_champID103 (0.000038)
# 527. t0p_support_champID37 (0.000037)
# 528. t1p_top_lane_champID18 (0.000037)
# 529. t1p_jungle_champID16 (0.000036)
# 530. t1p_top_lane_champID42 (0.000035)
# 531. t0p_jungle_champID67 (0.000035)
# 532. t0p_jungle_champID93 (0.000035)
# 533. t0p_top_lane_champID73 (0.000035)
# 534. t0p_ad_carry_champID95 (0.000035)
# 535. t1p_jungle_champID8 (0.000035)
# 536. t1p_jungle_champID1 (0.000035)
# 537. t1p_mid_lane_champID54 (0.000035)
# 538. t0p_jungle_champID64 (0.000035)
# 539. t0p_support_champID100 (0.000035)
# 540. t0p_mid_lane_champID16 (0.000034)
# 541. t1p_support_champID14 (0.000034)
# 542. t0p_support_champID8 (0.000034)
# 543. t1p_mid_lane_champID100 (0.000034)
# 544. t0p_ad_carry_champID74 (0.000034)
# 545. t1p_support_champID57 (0.000034)
# 546. t0p_ad_carry_champID63 (0.000033)
# 547. t0p_ad_carry_champID66 (0.000033)
# 548. t0p_support_champID32 (0.000033)
# 549. t0p_top_lane_champID54 (0.000033)
# 550. t1p_top_lane_champID118 (0.000032)
# 551. t1p_mid_lane_champID97 (0.000032)
# 552. t0p_support_champID0 (0.000032)
# 553. t1p_mid_lane_champID28 (0.000032)
# 554. t1p_jungle_champID97 (0.000032)
# 555. t1p_top_lane_champID37 (0.000031)
# 556. t1p_support_champID122 (0.000030)
# 557. t1p_top_lane_champID91 (0.000030)
# 558. t1p_mid_lane_champID1 (0.000030)
# 559. t1p_top_lane_champID24 (0.000030)
# 560. t1p_jungle_champID73 (0.000029)
# 561. t0p_ad_carry_champID11 (0.000029)
# 562. t1p_jungle_champID18 (0.000029)
# 563. t1p_mid_lane_champID81 (0.000028)
# 564. t0p_mid_lane_champID87 (0.000028)
# 565. t1p_mid_lane_champID33 (0.000027)
# 566. t0p_jungle_champID15 (0.000026)
# 567. t0p_top_lane_champID130 (0.000026)
# 568. t0p_support_champID76 (0.000026)
# 569. t0p_support_champID4 (0.000026)
# 570. t1p_support_champID49 (0.000023)
# 571. t1p_top_lane_champID8 (0.000022)
# 572. t1p_support_champID40 (0.000021)
# 573. t0p_jungle_champID56 (0.000020)
# 574. t0p_support_champID3 (0.000020)
# 575. t0p_support_champID62 (0.000020)
# 576. t1p_top_lane_champID16 (0.000019)
# 577. t1p_ad_carry_champID11 (0.000018)
# 578. t0p_jungle_champID72 (0.000018)
# 579. t0p_ad_carry_champID1 (0.000017)
# 580. t0p_ad_carry_champID35 (0.000017)
# 581. t1p_ad_carry_champID82 (0.000016)
# 582. t0p_mid_lane_champID128 (0.000016)
# 583. t1p_support_champID2 (0.000015)
# 584. t0p_support_champID79 (0.000013)
# 585. t0p_jungle_champID94 (0.000013)
# 586. t1p_top_lane_champID71 (0.000013)
# 587. t0p_mid_lane_champID7 (0.000012)
# 588. t0p_support_champID61 (0.000011)
# 589. t0p_mid_lane_champID77 (0.000011)
# 590. t1p_mid_lane_champID73 (0.000010)
# 591. t1p_jungle_champID27 (0.000008)
# 592. t1p_support_champID37 (0.000008)
# 593. t0p_support_champID22 (0.000008)
# 594. t1p_support_champID62 (0.000007)
# 595. t0p_mid_lane_champID5 (0.000006)
# 596. t1p_ad_carry_champID78 (0.000006)
# 597. t0p_support_champID97 (0.000006)
# 598. t1p_top_lane_champID29 (0.000005)
# 599. t0p_jungle_champID20 (0.000004)
# 600. t1p_top_lane_champID75 (0.000004)
# 601. t1p_support_champID78 (0.000002)
# 602. t1p_top_lane_champID4 (0.000002)
# 603. t1p_support_champID26 (0.000001)
# 604. t1p_ad_carry_champID126 (0.000001)
# 605. t0p_jungle_champID96 (0.000000)
# 606. t1p_mid_lane_champID74 (0.000000)
# 607. t1p_ad_carry_champID34 (0.000000)
# 608. t1p_support_champID43 (0.000000)
# 609. t0p_support_champID14 (0.000000)
# 610. t0p_support_champID23 (0.000000)
# 611. t0p_support_champID20 (0.000000)
# 612. t0p_top_lane_champID89 (0.000000)
# 613. t0p_top_lane_champID94 (0.000000)
# 614. t0p_top_lane_champID85 (0.000000)
# 615. t0p_top_lane_champID99 (0.000000)
# 616. t0p_support_champID13 (0.000000)
# 617. t0p_top_lane_champID97 (0.000000)
# 618. t0p_support_champID26 (0.000000)
# 619. t0p_support_champID9 (0.000000)
# 620. t0p_top_lane_champID93 (0.000000)
# 621. t0p_jungle_champID68 (0.000000)
# 622. t0p_support_champID64 (0.000000)
# 623. t0p_support_champID33 (0.000000)
# 624. t0p_support_champID88 (0.000000)
# 625. t0p_support_champID89 (0.000000)
# 626. t0p_top_lane_champID41 (0.000000)
# 627. t0p_top_lane_champID42 (0.000000)
# 628. t0p_top_lane_champID43 (0.000000)
# 629. t0p_top_lane_champID44 (0.000000)
# 630. t0p_top_lane_champID45 (0.000000)
# 631. t0p_top_lane_champID49 (0.000000)
# 632. t0p_support_champID87 (0.000000)
# 633. t0p_support_champID90 (0.000000)
# 634. t0p_support_champID86 (0.000000)
# 635. t0p_support_champID85 (0.000000)
# 636. t0p_top_lane_champID51 (0.000000)
# 637. t0p_top_lane_champID52 (0.000000)
# 638. t0p_support_champID83 (0.000000)
# 639. t0p_top_lane_champID53 (0.000000)
# 640. t0p_top_lane_champID55 (0.000000)
# 641. t0p_top_lane_champID40 (0.000000)
# 642. t0p_support_champID91 (0.000000)
# 643. t0p_support_champID34 (0.000000)
# 644. t0p_support_champID104 (0.000000)
# 645. t0p_support_champID111 (0.000000)
# 646. t0p_support_champID110 (0.000000)
# 647. t0p_support_champID109 (0.000000)
# 648. t0p_support_champID108 (0.000000)
# 649. t0p_top_lane_champID17 (0.000000)
# 650. t0p_support_champID106 (0.000000)
# 651. t0p_support_champID105 (0.000000)
# 652. t0p_top_lane_champID25 (0.000000)
# 653. t0p_support_champID92 (0.000000)
# 654. t0p_top_lane_champID29 (0.000000)
# 655. t0p_support_champID101 (0.000000)
# 656. t0p_top_lane_champID34 (0.000000)
# 657. t0p_support_champID96 (0.000000)
# 658. t0p_support_champID95 (0.000000)
# 659. t0p_support_champID94 (0.000000)
# 660. t0p_support_champID93 (0.000000)
# 661. t0p_top_lane_champID56 (0.000000)
# 662. t0p_top_lane_champID57 (0.000000)
# 663. t0p_top_lane_champID58 (0.000000)
# 664. t0p_support_champID52 (0.000000)
# 665. t0p_top_lane_champID77 (0.000000)
# 666. t0p_top_lane_champID78 (0.000000)
# 667. t0p_support_champID57 (0.000000)
# 668. t0p_top_lane_champID79 (0.000000)
# 669. t0p_support_champID56 (0.000000)
# 670. t0p_support_champID54 (0.000000)
# 671. t0p_support_champID53 (0.000000)
# 672. t0p_support_champID51 (0.000000)
# 673. t0p_top_lane_champID60 (0.000000)
# 674. t0p_support_champID49 (0.000000)
# 675. t0p_top_lane_champID80 (0.000000)
# 676. t0p_support_champID47 (0.000000)
# 677. t0p_top_lane_champID81 (0.000000)
# 678. t0p_support_champID39 (0.000000)
# 679. t0p_top_lane_champID83 (0.000000)
# 680. t0p_top_lane_champID84 (0.000000)
# 681. t0p_support_champID59 (0.000000)
# 682. t0p_top_lane_champID76 (0.000000)
# 683. t0p_support_champID63 (0.000000)
# 684. t0p_support_champID65 (0.000000)
# 685. t0p_support_champID80 (0.000000)
# 686. t0p_top_lane_champID62 (0.000000)
# 687. t0p_top_lane_champID63 (0.000000)
# 688. t0p_top_lane_champID64 (0.000000)
# 689. t0p_top_lane_champID65 (0.000000)
# 690. t0p_support_champID77 (0.000000)
# 691. t0p_top_lane_champID66 (0.000000)
# 692. t0p_support_champID74 (0.000000)
# 693. t0p_support_champID73 (0.000000)
# 694. t0p_support_champID72 (0.000000)
# 695. t0p_top_lane_champID69 (0.000000)
# 696. t0p_top_lane_champID70 (0.000000)
# 697. t0p_top_lane_champID71 (0.000000)
# 698. t0p_support_champID68 (0.000000)
# 699. t0p_top_lane_champID72 (0.000000)
# 700. t0p_top_lane_champID100 (0.000000)
# 701. t0p_top_lane_champID128 (0.000000)
# 702. t0p_top_lane_champID101 (0.000000)
# 703. t0p_jungle_champID118 (0.000000)
# 704. t0p_jungle_champID129 (0.000000)
# 705. t0p_jungle_champID128 (0.000000)
# 706. t0p_jungle_champID127 (0.000000)
# 707. t0p_jungle_champID49 (0.000000)
# 708. t0p_jungle_champID50 (0.000000)
# 709. t0p_support_champID113 (0.000000)
# 710. t0p_jungle_champID51 (0.000000)
# 711. t0p_jungle_champID52 (0.000000)
# 712. t0p_jungle_champID54 (0.000000)
# 713. t0p_jungle_champID125 (0.000000)
# 714. t0p_jungle_champID124 (0.000000)
# 715. t0p_jungle_champID123 (0.000000)
# 716. t0p_jungle_champID122 (0.000000)
# 717. t0p_jungle_champID121 (0.000000)
# 718. t0p_jungle_champID58 (0.000000)
# 719. t0p_jungle_champID59 (0.000000)
# 720. t0p_jungle_champID120 (0.000000)
# 721. t0p_jungle_champID130 (0.000000)
# 722. t0p_jungle_champID131 (0.000000)
# 723. t0p_jungle_champID132 (0.000000)
# 724. t0p_mid_lane_champID23 (0.000000)
# 725. t0p_jungle_champID31 (0.000000)
# 726. t0p_jungle_champID35 (0.000000)
# 727. t0p_jungle_champID36 (0.000000)
# 728. t0p_mid_lane_champID35 (0.000000)
# 729. t0p_jungle_champID39 (0.000000)
# 730. t0p_jungle_champID40 (0.000000)
# 731. t0p_mid_lane_champID24 (0.000000)
# 732. t0p_mid_lane_champID22 (0.000000)
# 733. t0p_jungle_champID133 (0.000000)
# 734. t0p_jungle_champID44 (0.000000)
# 735. t0p_jungle_champID47 (0.000000)
# 736. t0p_mid_lane_champID6 (0.000000)
# 737. t0p_mid_lane_champID4 (0.000000)
# 738. t0p_mid_lane_champID3 (0.000000)
# 739. t0p_mid_lane_champID2 (0.000000)
# 740. t0p_mid_lane_champID0 (0.000000)
# 741. t0p_jungle_champID119 (0.000000)
# 742. t0p_jungle_champID60 (0.000000)
# 743. t0p_mid_lane_champID47 (0.000000)
# 744. t0p_jungle_champID116 (0.000000)
# 745. t0p_jungle_champID90 (0.000000)
# 746. t0p_jungle_champID89 (0.000000)
# 747. t0p_jungle_champID87 (0.000000)
# 748. t0p_jungle_champID86 (0.000000)
# 749. t0p_jungle_champID85 (0.000000)
# 750. t0p_jungle_champID84 (0.000000)
# 751. t0p_jungle_champID81 (0.000000)
# 752. t0p_jungle_champID80 (0.000000)
# 753. t0p_jungle_champID79 (0.000000)
# 754. t0p_jungle_champID78 (0.000000)
# 755. t0p_jungle_champID77 (0.000000)
# 756. t0p_jungle_champID75 (0.000000)
# 757. t0p_jungle_champID74 (0.000000)
# 758. t0p_jungle_champID71 (0.000000)
# 759. t0p_jungle_champID70 (0.000000)
# 760. t0p_jungle_champID69 (0.000000)
# 761. t0p_jungle_champID66 (0.000000)
# 762. t0p_jungle_champID91 (0.000000)
# 763. t0p_jungle_champID92 (0.000000)
# 764. t0p_jungle_champID95 (0.000000)
# 765. t0p_jungle_champID108 (0.000000)
# 766. t0p_jungle_champID115 (0.000000)
# 767. t0p_jungle_champID114 (0.000000)
# 768. t0p_jungle_champID61 (0.000000)
# 769. t0p_jungle_champID112 (0.000000)
# 770. t0p_jungle_champID111 (0.000000)
# 771. t0p_jungle_champID110 (0.000000)
# 772. t0p_jungle_champID109 (0.000000)
# 773. t0p_jungle_champID107 (0.000000)
# 774. t0p_jungle_champID97 (0.000000)
# 775. t0p_jungle_champID106 (0.000000)
# 776. t0p_jungle_champID105 (0.000000)
# 777. t0p_jungle_champID65 (0.000000)
# 778. t0p_jungle_champID103 (0.000000)
# 779. t0p_jungle_champID100 (0.000000)
# 780. t0p_jungle_champID99 (0.000000)
# 781. t0p_jungle_champID98 (0.000000)
# 782. t0p_jungle_champID27 (0.000000)
# 783. t0p_jungle_champID26 (0.000000)
# 784. t0p_top_lane_champID102 (0.000000)
# 785. t0p_mid_lane_champID99 (0.000000)
# 786. t0p_mid_lane_champID117 (0.000000)
# 787. t0p_mid_lane_champID116 (0.000000)
# 788. t0p_mid_lane_champID113 (0.000000)
# 789. t0p_top_lane_champID117 (0.000000)
# 790. t0p_top_lane_champID118 (0.000000)
# 791. t0p_mid_lane_champID112 (0.000000)
# 792. t0p_mid_lane_champID111 (0.000000)
# 793. t0p_mid_lane_champID110 (0.000000)
# 794. t0p_mid_lane_champID109 (0.000000)
# 795. t0p_mid_lane_champID107 (0.000000)
# 796. t0p_mid_lane_champID106 (0.000000)
# 797. t0p_mid_lane_champID105 (0.000000)
# 798. t0p_top_lane_champID119 (0.000000)
# 799. t0p_mid_lane_champID102 (0.000000)
# 800. t0p_top_lane_champID120 (0.000000)
# 801. t0p_top_lane_champID121 (0.000000)
# 802. t0p_mid_lane_champID100 (0.000000)
# 803. t0p_mid_lane_champID118 (0.000000)
# 804. t0p_mid_lane_champID119 (0.000000)
# 805. t0p_mid_lane_champID120 (0.000000)
# 806. t0p_mid_lane_champID131 (0.000000)
# 807. t0p_top_lane_champID105 (0.000000)
# 808. t0p_top_lane_champID106 (0.000000)
# 809. t0p_top_lane_champID108 (0.000000)
# 810. t0p_mid_lane_champID133 (0.000000)
# 811. t0p_top_lane_champID109 (0.000000)
# 812. t0p_mid_lane_champID132 (0.000000)
# 813. t0p_top_lane_champID110 (0.000000)
# 814. t0p_top_lane_champID111 (0.000000)
# 815. t0p_mid_lane_champID121 (0.000000)
# 816. t0p_top_lane_champID113 (0.000000)
# 817. t0p_mid_lane_champID127 (0.000000)
# 818. t0p_mid_lane_champID126 (0.000000)
# 819. t0p_mid_lane_champID125 (0.000000)
# 820. t0p_top_lane_champID114 (0.000000)
# 821. t0p_top_lane_champID116 (0.000000)
# 822. t0p_mid_lane_champID122 (0.000000)
# 823. t0p_top_lane_champID122 (0.000000)
# 824. t0p_mid_lane_champID98 (0.000000)
# 825. t0p_mid_lane_champID50 (0.000000)
# 826. t0p_mid_lane_champID96 (0.000000)
# 827. t0p_jungle_champID9 (0.000000)
# 828. t0p_mid_lane_champID71 (0.000000)
# 829. t0p_jungle_champID13 (0.000000)
# 830. t0p_jungle_champID14 (0.000000)
# 831. t0p_mid_lane_champID70 (0.000000)
# 832. t0p_mid_lane_champID69 (0.000000)
# 833. t0p_jungle_champID16 (0.000000)
# 834. t0p_mid_lane_champID65 (0.000000)
# 835. t0p_jungle_champID18 (0.000000)
# 836. t0p_mid_lane_champID62 (0.000000)
# 837. t0p_mid_lane_champID61 (0.000000)
# 838. t0p_mid_lane_champID60 (0.000000)
# 839. t0p_mid_lane_champID59 (0.000000)
# 840. t0p_mid_lane_champID58 (0.000000)
# 841. t0p_mid_lane_champID57 (0.000000)
# 842. t0p_jungle_champID21 (0.000000)
# 843. t0p_mid_lane_champID51 (0.000000)
# 844. t0p_jungle_champID0 (0.000000)
# 845. t0p_top_lane_champID133 (0.000000)
# 846. t0p_top_lane_champID132 (0.000000)
# 847. t0p_mid_lane_champID89 (0.000000)
# 848. t0p_mid_lane_champID95 (0.000000)
# 849. t0p_top_lane_champID124 (0.000000)
# 850. t0p_mid_lane_champID94 (0.000000)
# 851. t0p_mid_lane_champID93 (0.000000)
# 852. t0p_mid_lane_champID92 (0.000000)
# 853. t0p_mid_lane_champID91 (0.000000)
# 854. t0p_top_lane_champID126 (0.000000)
# 855. t0p_mid_lane_champID88 (0.000000)
# 856. t0p_mid_lane_champID76 (0.000000)
# 857. t0p_mid_lane_champID85 (0.000000)
# 858. t0p_mid_lane_champID84 (0.000000)
# 859. t0p_mid_lane_champID83 (0.000000)
# 860. t0p_top_lane_champID129 (0.000000)
# 861. t0p_mid_lane_champID80 (0.000000)
# 862. t0p_mid_lane_champID79 (0.000000)
# 863. t0p_top_lane_champID131 (0.000000)
# 864. t0p_support_champID112 (0.000000)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-17-539437415a59> in <module>()
#      36
#      37 for i, f in enumerate(features):
# ---> 38     print("%d. %s (%f)" % (i+1, features[indices[i]], importances[indices[i]]))
#      39
#      40
#
# IndexError: list index out of range

# %%
# using tensorflow
import tensorflow as tf

# create test train split
from sklearn.cross_validation import train_test_split
X_train, X_test, y_train, y_test = train_test_split(games, winners, test_size=0.30, random_state=42)

def weight_variable(shape):
    initial = tf.truncated_normal(shape, stddev=0.1)
    return tf.Variable(initial)

def bias_variable(shape):
    initial = tf.constant(0.1, shape=shape)
    return tf.Variable(initial)

def conv2d(x, W):
    return tf.nn.conv2d(x, W, strides=[1, 1, 1, 1], padding='SAME')

def max_pool_2x2(x):
    return tf.nn.max_pool(x, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')

sess = tf.InteractiveSession()

inputs = 64

x = tf.placeholder(tf.float32, shape=[None, inputs])
y_ = tf.placeholder(tf.float32, shape=[None, 2])

# first Convolutional Layer
W_conv1 = weight_variable([5, 5, 1, 32])
b_conv1 = bias_variable([32])
x_image = tf.reshape(x, [-1,8,8,1])
h_conv1 = tf.nn.relu(conv2d(x_image, W_conv1) + b_conv1)
h_pool1 = max_pool_2x2(h_conv1)

# second Convolutional Layer
W_conv2 = weight_variable([5, 5, 32, 64])
b_conv2 = bias_variable([64])
h_conv2 = tf.nn.relu(conv2d(h_pool1, W_conv2) + b_conv2)
h_pool2 = max_pool_2x2(h_conv2)

# densely connected Layer
W_fc1 = weight_variable([2*2*64, 1024])
b_fc1 = bias_variable([1024])
h_pool2_flat = tf.reshape(h_pool2, [-1, 2*2*64])
h_fc1 = tf.nn.relu(tf.matmul(h_pool2_flat, W_fc1) + b_fc1)

# Dropout: reduce overfitting
keep_prob = tf.placeholder(tf.float32)
h_fc1_drop = tf.nn.dropout(h_fc1, keep_prob)

# readout Layer
W_fc2 = weight_variable([1024, 2])
b_fc2 = bias_variable([2])
y_conv = tf.matmul(h_fc1_drop, W_fc2) + b_fc2


cross_entropy = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(y_conv, y_))
train_step = tf.train.AdamOptimizer(1e-4).minimize(cross_entropy)
correct_prediction = tf.equal(tf.argmax(y_conv,1), tf.argmax(y_,1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
sess.run(tf.global_variables_initializer())
for i in range(2000):
    idx = np.random.choice(np.arange(len(X_train)), 100, replace=False) # get batch size of 500 w/ matching indices
    X_train_batch = [X_train[i] for i in idx]
    y_train_batch = [y_train[i] for i in idx]
    if i%100 == 0:
        train_accuracy = accuracy.eval(feed_dict={x:X_test, y_: y_test, keep_prob: 1.0})
        print("step %d, training accuracy %g"%(i, train_accuracy))
    train_step.run(feed_dict={x: X_train_batch, y_: y_train_batch, keep_prob: 0.5})

print("test accuracy %g"%accuracy.eval(feed_dict={x: X_test, y_: y_test, keep_prob: 1.0}))
# Out:
# step 0, training accuracy 0.520186
# step 100, training accuracy 0.524845
# step 200, training accuracy 0.524845
# step 300, training accuracy 0.504658
# step 400, training accuracy 0.51087
# step 500, training accuracy 0.476708
# step 600, training accuracy 0.498447
# step 700, training accuracy 0.501553
# step 800, training accuracy 0.473602
# step 900, training accuracy 0.498447
# step 1000, training accuracy 0.473602
# step 1100, training accuracy 0.493789
# step 1200, training accuracy 0.526398
# step 1300, training accuracy 0.503106
# step 1400, training accuracy 0.515528
# step 1500, training accuracy 0.468944
# step 1600, training accuracy 0.465839
# step 1700, training accuracy 0.523292
# step 1800, training accuracy 0.478261
# step 1900, training accuracy 0.517081
# test accuracy 0.531056
